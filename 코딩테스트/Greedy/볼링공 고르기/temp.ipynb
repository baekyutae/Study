# %% [markdown]
# 볼링공의 무게는 1부터 m
#
# 공의 갯수는 n
#
# 같은 무게의 공도 각각 다른 공으로 취급
# 각공의 번호가 차례대로 1번부터 n번까지 부여
#
# 두사람이 공을 고르는 경우의 수 / 단 서로 무게가 달라야함
#
#
# 1 3 2 3 2
#
# 1 2 2 3 3
#
# 사람 a b
#
#
#
# 7 6 4 4 4

# %%
test = [1,5,4,3,2,4,5,2]

list = []



for index, i in enumerate(test):
    for j in test[index+1:]:
        print(i,j)
# Out:
# 1 5
# 1 4
# 1 3
# 1 2
# 1 4
# 1 5
# 1 2
# 5 4
# 5 3
# 5 2
# 5 4
# 5 5
# 5 2
# 4 3
# 4 2
# 4 4
# 4 5
# 4 2
# 3 2
# 3 4
# 3 5
# 3 2
# 2 4
# 2 5
# 2 2
# 4 5
# 4 2
# 5 2

# %%
n, m = map(int, input().split())

Ball_weight = map(int, input().split())



def Select_Ball(n,m,Ball_weight):
    # 공의 무게 m이 최대 10
    # 공의 무게 별 갯수를 기록하기 위해 만든 배열(index 0은 무게 0이니 11개 만듬)
    array = [0] * 11
    
    for x in Ball_weight:
        array[x] += 1
    # print(array)
    result = 0
    for i in range(1, m+1):
        n -= array[i] # 들고있는 무게의 공 갯수 제외
        result += array[i] * n

    return(result)

Select_Ball(n,m,Ball_weight)
# Out:
# 10

# %%
# 테스트 케이스

# 1.모두 같은 무게의 공일때 == 0
5 3
[3,3,3,3,3]

# 2. 하나 빼고 다 무게가 같을 때 == n-1

# 3. 공이 하나 일때 == 0

# 4. 모두 다른 무게의 공일때
