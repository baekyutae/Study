# %% [markdown]
# 입력
# 식량창고 n개 (3<= n <=100)
# 각 식량창고에 저장된 식량의 개수 k  (0<= k <= 1000)
#
#
# 출력
# 개미 전사가 얻을 수 있는 식량의 최대값
#
# 단 최소 한칸 떨어진 식량 창고를 약탈해야한다.
#
# -----------------
#
# 한칸 이상 떨어진 식량창고 조합과 그 조합의 식량 총량을 알아야함
#
# 붙어 있는지 확인하는 방법
#
# 창고별 인덱스 끼리 빼서(큰수-작은수) 1이 나오면 붙어 있는 것
#
# 조합을 만드는법
#
#
# 한번 방문한 식량 창고는 갯수를 아니깐 또 확인 안하고 기록해뒀다 써먹으면 이득일지도...?
#
#
# 10개
#
#
# 1 20 4 9 2 25 11 5 8 4
#
# 0번 인덱스는 2번부터 끝까지
# 1번 안덱스는 3번부터 끝까지
#
# def ant_worrior(창고리스트):
#     인접한 창고가 아닌 경우에
#         창고 조합을 만듬
#         총 식량을 산출
#         산출할때마다 결과 리스트에 저장
#     가장 큰값을 return
