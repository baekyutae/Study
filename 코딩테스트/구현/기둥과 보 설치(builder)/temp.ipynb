# %% [markdown]
# n*n 사이즈의 정사각 벽
#
# 기둥: 바닥, 다른 기둥 위, 보의 한쪽 끝부분 위
# 보: 한쪽 끝부분이 기둥 위, 양쪽 둘다 다른 보에 연결
#
# n => 벽면의 사이즈
#
# build_frame = [x,y,a,b]
#
# x,y = 설치 또는 삭제 좌표
#
# a = 0은 기둥 1 은 보
# b= 0은 삭제 1은 설치
#
# 구조물을 겹치도록 설치 또는 없는 구조물을 삭제하지는 않음
#
# n과 build_frame 입력에 따라 구조물을 출력
#
# answer = [x,y,a]
#
# => 기둥의  좌표, 기둥인지 보인지
#
#
# 일단 n*n 사이즈의 벽이있어야 함
#
#
#
# def builder(n, build_frame):
#     make n*n wall
#     build_frame의 원소(배열)를 하나씩 꺼냄
#         기둥과 보를 설치
#
#         기둥과 보를  삭제
#             b가 0일때 x,y가 같은 것을 배열에서 삭제
#         answer에 결과저장
#         def checker(answer)
#         checker의 결과가 true면 확정
#         checker의 결과가 false면 롤백
#
#     return answer
#
# def checker(answer):
#     설치 및 삭제 했을때 조건에 위배 되지 않는지 체크
#     설치/삭제가 기둥 일때 체크
#     설치/삭제가 기둥 일때 체크

# %% [markdown]
# def builder(n, build_frame):
#     make n*n wall
#     build_frame의 원소(배열)를 하나씩 꺼냄
#
#         기둥과 보를 설치 하는 경우
#             answer에 더함
#             checker()로 확인
#             문제 없으면 유지 규칙 위반이면 remove
#
#         기둥과 보를  삭제 하는 경우
#             answer에서 remove
#             checker()로 확인
#             문제 없으면 유지 규칙 위반이면 append
#
#
#
#     return sort(answer)
#
# def checker(answer):
#     설치 및 삭제 했을때 조건에 위배 되지 않는지 체크
#     설치/삭제가 기둥 일때 체크
#         밑에 기둥이 있거나, 보의 끝에 위치
#
#     설치/삭제가 기둥 일때 체크
#         양쪽에 보가 연결되어 있거나 한쪽 끝 부분에 기둥이 있어야함

# %%
def builder(n, build_frame):
    wall = [[0]*(n) for _ in range(n)]
    


    answer = [[]]
    return answer
