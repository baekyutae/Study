# %%
preorder는 root를 뽑는 배열
inorder는 root 기준으로 left/right 범위를 나누는 배열
pre_idx는 preorder에서 다음 root를 가리키는 포인터
build(left, right)는 inorder[left:right] 범위로 서브트리를 만든다


1. preorder의 역할 한 줄 쓰기
2. inorder의 역할 한 줄 쓰기
3. build(left, right)의 의미 쓰기
4. base case 쓰기: left > right면 None
5. root_val = preorder[pre_idx]
6. mid = inorder에서 root 위치
7. left/right 재귀

# %% [markdown]
# 두 intger array가 주어짐 preorder는 트리의 전위 순회 inorder는 tree의 중위 순회
#
# 두 배열로 이진트리를 만들어라
#
# preorder 에 첫번째 원소는 무조건 root node임
#
# 그렇다면 inorder에서 해당 원소를 찾으면
# 그 원소의 좌측은 left subtree
# 우측은 right subtree
#
# preorder 2,3번째 노드는 무조건 root node의 left, right 자식 노드
#
# class Solution:
#     def buildTree(self, preorder: List[int], inorder: List[int]) -> Optional[TreeNode]:
