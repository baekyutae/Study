# %% [markdown]
# root 부터 leaf까지 각 노드의 val을 더했을 때
# target과 동일한 정수라면 true를 반환  아니면 false
#
# 탐색을 해봐야 알수 있음
# 각 경로별로 호출한다음 반환하면서 val을 합산
# root까지 다 더한뒤 target과 비교해야함
#
# class Solution:
#     def hasPathSum(self, root: Optional[TreeNode], targetSum: int) -> bool:
#
#         경로 선택 left or right
#
#         while root is not None:
#             root에서 출발
#             leaf 노드까지 호출하며
#
#             sum += val
#
#         if sum == targetSum:
#             return True
#
#         안간 경로로 이동
#
#         return False

# %% [markdown]
# class Solution:
#     def hasPathSum(self, root: Optional[TreeNode], targetSum: int) -> bool:
#         if root is None:
#             return None
#
#         remain = targetSum - root.val
#
#         if root.left and root.right is None:
#             return targetSum == root.val
#
#         left_path = self.hasPathSum(root.lef, remain)
#         right_path = self.hasPathSum(root.right, remain)
