# %% [markdown]
# 주어진 문자열 s의 substring중 가장 긴 substring의 길이를 반환
#
#
# ```
# class Solution:
#     def lengthOfLongestSubstring(self, s: str) -> int:
#         문자열 S를 왼쪽에서부터 더해나감
#             substing 에서 중복되는 문자를 만남
#                 해당 문자를 만나기 전까지를 최대 길이로 기록,
#                 왼쪽부터 중복되는 문자가 사라질떄 까지 한칸씩 이동
#
#         사라지고 나면 다시 문자를 더해나감
#
#         더해나갈 때 사용하는 포인터 하나, 중복 제거해 나가는 포인터 하나 필요함
#
#
# ```
