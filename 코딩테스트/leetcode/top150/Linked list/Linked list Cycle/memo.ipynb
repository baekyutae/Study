# %% [markdown]
# 링크드 리스트의 헤드부터 next 포인터를 따라가서 이전에 만났던 노드를 한번더 만나는
# 즉 순회하는 지 여부를 판별
#
# 입력: head와 pos
#
# 방문여부 기록 필요
# ListNode를 상속받아, 방문 여부도 기록 하는 변수를 추가?
#
#
# 기록용 노드
# class Check_node(ListNode):
#     def __init__(self,x,check):
#         self.val = x
#         self.next = None
#         self.check = false
#
#
# class Solution:
#     def hasCycle(self, head: Optional[ListNode]) -> bool:
#         temp = Check_node()
#
#
#         while head is not None
#
#             if temp.check = false
#                 temp.check = true
#                 temp.next = head.next
#
#             else:
#                 return true
#
#
#         reutrn false

# %%
class Check_node(ListNode):
    def __init__(self,x,check):
        self.check = false
        
class Solution:
    def hasCycle(self, head: Optional[ListNode]) -> bool:
        temp = Check_node()


        while head is not None:
            
            if temp.check == false:
                temp.check = true
                temp.next = head.next

            else:
                return true

        
        reutrn false
