# %% [markdown]
# 한 층씩 순회하며 각 노드의 value를 담아 리스트 형태로 반환
#
# 결과반환용 리스트 생성
# 노드를 큐에 담음
#
# 리스트에 node.val을 저장
# node를 popleft
# => 근데 같은 층의 noed들은 같은 [node.val, node.val] 이렇게 리스트에 저장이 되어야함
#
#
#
# node의 자식노드가 있으면
# 큐에 append
#
# 큐가 완전히 빌때 까지 반복
